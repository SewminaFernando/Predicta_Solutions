# %%
import pandas as pd
from prophet import Prophet

# Load the updated dataset
data = pd.read_csv('data/part_1/historical_weather_without_outliers.csv')

# Convert the 'date' column to datetime format
data['date'] = pd.to_datetime(data['date'])

# Function to train a Prophet model for a given city
def train_prophet_model(city_data):
    # Prepare the data for Prophet
    prophet_data = city_data.rename(columns={'date': 'ds', 'avg_temp_c': 'y'})

    # Define the Prophet model
    model = Prophet()

    # Fit the model
    model.fit(prophet_data)

    return model

# Dictionary to store Prophet models for each city
prophet_models = {}

# Train a Prophet model for each city
for city_id, city_data in data.groupby('city_id'):
    prophet_models[city_id] = train_prophet_model(city_data)

# Function to forecast using the trained Prophet model
def forecast_prophet_model(model, steps):
    future = model.make_future_dataframe(periods=steps)
    forecast = model.predict(future)
    return forecast.tail(steps)['yhat']

# Dictionary to store forecasted values for each city
prophet_forecasts = {}

# Forecast the first week of 2019 for each city and print the forecasted values
for city_id, model in prophet_models.items():
    forecast = forecast_prophet_model(model, steps=7)
    prophet_forecasts[city_id] = forecast
    print(f"Forecasted values for city {city_id}:")
    print(forecast.values)
    print("\n")

# Save the forecasted values to a CSV file
forecast_data = []
submission_id = 1
for city_id, forecast in prophet_forecasts.items():
    for temp in forecast:
        forecast_data.append({'submission_ID': submission_id, 'avg_temp_c': round(temp, 2)})
        submission_id += 1

forecast_df = pd.DataFrame(forecast_data)
forecast_df.to_csv('data/part_1/forcasted_data/prophet.csv', index=False)

print("Forecast data has been saved to 'prophet.csv'")
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/6kxulper.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/voywi59s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69366', 'data', 'file=/tmp/tmpea5xgirb/6kxulper.json', 'init=/tmp/tmpea5xgirb/voywi59s.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelnvm6hqp5/prophet_model-20240623084601.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/1kq8cxfu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/8z5_e7ei.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44100', 'data', 'file=/tmp/tmpea5xgirb/1kq8cxfu.json', 'init=/tmp/tmpea5xgirb/8z5_e7ei.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modela3miofld/prophet_model-20240623084602.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/b5naef6a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/1g5zmg5z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27348', 'data', 'file=/tmp/tmpea5xgirb/b5naef6a.json', 'init=/tmp/tmpea5xgirb/1g5zmg5z.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modeldocn8zkf/prophet_model-20240623084602.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/vit1ony5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/75drjmht.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35230', 'data', 'file=/tmp/tmpea5xgirb/vit1ony5.json', 'init=/tmp/tmpea5xgirb/75drjmht.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model876oguu7/prophet_model-20240623084603.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/x5razrgt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/1kh_csps.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96977', 'data', 'file=/tmp/tmpea5xgirb/x5razrgt.json', 'init=/tmp/tmpea5xgirb/1kh_csps.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelt_v6_9up/prophet_model-20240623084603.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/vnlu88jo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/k5l4ibzb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71476', 'data', 'file=/tmp/tmpea5xgirb/vnlu88jo.json', 'init=/tmp/tmpea5xgirb/k5l4ibzb.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelr31sulgy/prophet_model-20240623084604.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/lxn1iav8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/tv1y7nnr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90539', 'data', 'file=/tmp/tmpea5xgirb/lxn1iav8.json', 'init=/tmp/tmpea5xgirb/tv1y7nnr.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model4xm153e8/prophet_model-20240623084604.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/fms6i1c8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/dl_nbk4p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=421', 'data', 'file=/tmp/tmpea5xgirb/91bwxkw6.json', 'init=/tmp/tmpea5xgirb/xr_d2zyq.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelp2tldwwq/prophet_model-20240623084624.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/nol8015x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/owb46kzz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82207', 'data', 'file=/tmp/tmpea5xgirb/nol8015x.json', 'init=/tmp/tmpea5xgirb/owb46kzz.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelpejtdf8d/prophet_model-20240623084625.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/vqted12g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/mlv0s725.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38354', 'data', 'file=/tmp/tmpea5xgirb/vqted12g.json', 'init=/tmp/tmpea5xgirb/mlv0s725.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelhir3iyn9/prophet_model-20240623084625.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/8ez0vktj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/0lgb8vdp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96524', 'data', 'file=/tmp/tmpea5xgirb/8ez0vktj.json', 'init=/tmp/tmpea5xgirb/0lgb8vdp.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelv0txb6uk/prophet_model-20240623084626.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/aep35kb7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/stu1hu45.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22208', 'data', 'file=/tmp/tmpea5xgirb/aep35kb7.json', 'init=/tmp/tmpea5xgirb/stu1hu45.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modeleny7ile2/prophet_model-20240623084626.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ...
# 08:46:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/4k1me0vd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/55yhx0d0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2364', 'data', 'file=/tmp/tmpea5xgirb/4k1me0vd.json', 'init=/tmp/tmpea5xgirb/55yhx0d0.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model8yayhqy9/prophet_model-20240623084645.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/1qyn0mt_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/0ep3jl1b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95442', 'data', 'file=/tmp/tmpea5xgirb/1qyn0mt_.json', 'init=/tmp/tmpea5xgirb/0ep3jl1b.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelg8bxd108/prophet_model-20240623084645.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/c3g76ihn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/m6lek_0n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31743', 'data', 'file=/tmp/tmpea5xgirb/c3g76ihn.json', 'init=/tmp/tmpea5xgirb/m6lek_0n.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelj64zt21e/prophet_model-20240623084646.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/olkkkylr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/bvsj2z6b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90338', 'data', 'file=/tmp/tmpea5xgirb/olkkkylr.json', 'init=/tmp/tmpea5xgirb/bvsj2z6b.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model0ij57rqf/prophet_model-20240623084646.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 08:46:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 08:46:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Forecasted values for city C001:
# [8.12534245 7.7859671  7.43027215 7.08387369 6.88686383 7.00036552
#  7.06663429]
#
#
# Forecasted values for city C002:
# [14.62160551 14.51579733 14.34142385 14.16754365 14.07676506 13.93804321
#  13.83855313]
#
#
# Forecasted values for city C003:
# [26.76534691 26.81774132 26.76870766 26.75219564 26.81666036 26.79944366
#  26.74890758]
#
#
# Forecasted values for city C004:
# [-1.34358785 -1.42318059 -1.31901495 -1.18273041 -1.29588938 -1.41276121
#  -1.21816351]
#
#
# Forecasted values for city C005:
# [24.63367947 24.67141308 24.56640921 24.85579874 24.73533224 24.6443898
#  24.82038404]
#
#
# Forecasted values for city C007:
# [19.95925965 20.16326399 20.51458923 20.70686252 20.98839218 20.99685535
#  20.58607381]
#
#
# Forecasted values for city C008:
# [3.45774003 3.54523664 3.37724449 3.31059143 3.45934818 3.21205362
#  2.85192368]
#
#
# Forecasted values for city C009:
# [19.70425036 19.61883486 19.53278088 19.45923526 19.63583999 19.57534688
#  19.34840988]
#
#
# Forecasted values for city C010:
# [19.23158866 19.32830142 19.33038984 19.27756437 19.37116387 19.43381347
#  19.42442586]
#
#
# Forecasted values for city C011:
# [-2.36183642 -2.58700536 -2.932379   -3.03751903 -3.13058462 -3.30423097
#  -3.64481163]
#
#
# Forecasted values for city C012:
# [6.86256246 6.73279905 6.81970574 6.73687883 6.4602805  6.11942016
#  5.92963405]
#
#
# Forecasted values for city C013:
# [2.51721276 2.07432725 1.38498889 1.23245956 1.24871936 1.35917425
#  0.90399388]
#
#
# Forecasted values for city C014:
# [2.31654958 1.99665485 1.54836331 1.17580006 0.90296419 0.96926741
#  0.88956681]
#
#
# Forecasted values for city C015:
# [24.24009975 24.1909702  24.17504708 24.20106219 24.24908712 24.12635445
#  24.09755019]
#
#
# Forecasted values for city C016:
# [20.75980092 20.6636267  20.67697861 20.51817778 20.53749982 20.54777786
#  20.503576  ]
#
#
# Forecasted values for city C017:
# [27.57277307 27.58448958 27.59205403 27.59722796 27.64700159 27.65078423
#  27.60032468]
#
#
# Forecasted values for city C018:
# [-5.95246635 -6.07099422 -6.27355045 -6.22567026 -6.56186491 -7.02984401
#  -7.61743556]
#
#
# Forecasted values for city C020:
# [25.70594165 25.6922273  25.80892705 25.84199952 25.61236711 25.60000121
#  25.6906689 ]
#
#
# Forecasted values for city C022:
# [-4.66837069 -4.64401706 -4.7187633  -4.54298402 -4.69518611 -4.32276955
#  -4.17915561]
#
#
# Forecasted values for city C023:
# [27.02260023 26.97815475 26.95920842 26.77092365 26.68538848 26.57165385
#  26.5017736 ]
#
#
# Forecasted values for city C024:
# [5.40446347 5.27826111 5.00901154 4.8964533  4.92741952 4.71805659
#  4.46205287]
#
#
# Forecasted values for city C025:
# [3.09333552 3.12070516 2.96332076 2.97128505 3.08194311 2.87876995
#  2.48180947]
#
#
# Forecasted values for city C027:
# [-14.86339416 -15.40534994 -15.12381406 -15.13116147 -15.46163315
#  -15.47306649 -15.02824262]
#
#
# Forecasted values for city C028:
# [25.32773928 25.37250675 25.32914744 25.36650077 25.20383993 25.22834924
#  25.22687746]
#
#
# Forecasted values for city C029:
# [24.74247826 24.78835956 24.66079511 24.72654369 24.69501593 24.6614236
#  24.81260887]
#
#
# Forecasted values for city C030:
# [27.51065108 27.51877189 27.57014536 27.57535052 27.53280983 27.50533535
#  27.51361455]
#
#
# Forecasted values for city C031:
# [-1.23778636 -1.38637854 -1.64507108 -1.64884731 -1.60404873 -1.87872717
#  -2.01161834]
#
#
# Forecasted values for city C033:
# [-1.13271223 -1.39663771 -1.53320342 -1.5913821  -1.63411745 -1.88077395
#  -1.97467928]
#
#
# Forecasted values for city C034:
# [7.82508242 7.61304858 7.54468718 7.53120163 7.45998455 7.14474056
#  6.93040031]
#
#
# Forecasted values for city C035:
# [27.35431044 27.35468701 27.41343356 27.36098077 27.40071505 27.2923891
#  27.26352668]
#
#
# Forecasted values for city C036:
# [ 0.33660597  0.28113284  0.15121363  0.32169712  0.31184165  0.05536922
#  -0.15276248]
#
#
# Forecasted values for city C037:
# [4.05882795 4.07024373 4.05636744 4.19225005 4.07261498 3.73872302
#  3.52087432]
#
#
# Forecasted values for city C038:
# [28.20346477 28.1577378  28.16713069 28.17754609 28.11729835 28.05417174
#  28.01188541]
#
#
# Forecasted values for city C039:
# [11.7080249  11.43803357 11.19854785 10.83582402 10.69377944 10.72932859
#  10.75333644]
#
#
# Forecasted values for city C040:
# [27.44766675 27.39182078 27.43792359 27.34839781 27.45806912 27.41899634
#  27.25690699]
#
#
# Forecasted values for city C042:
# [20.23212711 20.20896413 20.27738611 20.4162025  20.52230516 20.46394483
#  20.54891424]
#
#
# Forecasted values for city C043:
# [2.86788186 2.74465886 2.40626648 2.3539413  2.38087896 2.28889494
#  1.88949223]
#
#
# Forecasted values for city C044:
# [12.09988777 12.31197951 12.56123014 12.73167846 12.68218579 12.63352265
#  12.66879223]
#
#
# Forecasted values for city C045:
# [27.81751191 27.80921915 27.75984286 27.80055876 27.69501478 27.72692597
#  27.7244619 ]
#
#
# Forecasted values for city C046:
# [6.02996772 6.067842   6.14109103 6.35147919 6.40599396 6.3254669
#  6.12135413]
#
#
# Forecasted values for city C047:
# [7.27437601 7.26375531 7.40316172 7.1880584  6.98989089 6.80946049
#  6.80760912]
#
#
# Forecasted values for city C048:
# [10.03064275  9.71265794  9.38355953  9.2558917   9.37601957  9.58806232
#   9.42542658]
#
#
# Forecasted values for city C049:
# [5.84083013 5.75118609 5.63060941 5.59122907 5.35821403 5.24130394
#  5.2639491 ]
#
#
# Forecasted values for city C051:
# [27.79965806 27.80429525 27.6883162  27.80713915 27.86919856 27.84727561
#  27.87931655]
#
#
# Forecasted values for city C053:
# [-4.2805366  -4.93327257 -5.08407364 -4.97401109 -5.11547874 -5.45712709
#  -5.73144756]
#
#
# Forecasted values for city C054:
# [-1.99834389 -2.25719044 -2.59466691 -2.62164701 -2.6824661  -2.80813853
#  -3.09269003]
#
#
# Forecasted values for city C055:
# [5.08500952 4.93072757 4.78406127 4.85811128 4.55366853 4.31543205
#  4.00745187]
#
#
# Forecasted values for city C056:
# [3.06123941 2.67794853 2.34336922 2.20262374 1.87710235 1.76907413
#  1.65466246]
#
#
# Forecasted values for city C057:
# [20.84205717 20.82546433 20.8185847  20.85792122 20.79179222 20.71837591
#  20.7124986 ]
#
#
# Forecasted values for city C058:
# [24.40814993 24.5134643  24.46222048 24.38556059 24.50300427 24.40075575
#  24.13897295]
#
#
# Forecasted values for city C059:
# [14.23938084 14.00747905 13.82245654 13.74413746 13.63098752 13.68429055
#  13.77686391]
#
#
# Forecasted values for city C061:
# [22.99520491 22.96921656 23.04056683 23.06802633 23.08749092 23.07003262
#  23.16254417]
#
#
# Forecasted values for city C062:
# [11.05024152 10.89550897 10.75688015 10.63437341 10.49386454 10.61662422
#  10.52724657]
#
#
# Forecasted values for city C064:
# [8.53006218 8.18527424 7.97772582 7.70227474 7.54712119 7.43815401
#  7.54995606]
#
#
# Forecasted values for city C065:
# [12.99944679 12.81112526 12.57739141 12.46223738 12.59289012 12.41266006
#  12.37330077]
#
#
# Forecasted values for city C066:
# [26.99091848 26.99554143 26.89424061 26.99499548 27.02190901 26.98204868
#  26.95607124]
#
#
# Forecasted values for city C067:
# [24.12713394 24.08545761 24.04488638 24.09592068 24.15772856 24.11805111
#  24.07995533]
#
#
# Forecasted values for city C068:
# [10.13875155 10.18294278 10.25534411 10.18985452 10.26031213 10.2290938
#  10.28775242]
#
#
# Forecasted values for city C069:
# [17.93046598 17.92845679 17.7990493  17.71400482 17.8441941  17.94882463
#  18.24690277]
#
#
# Forecasted values for city C070:
# [26.22768696 26.18607149 26.23377647 26.11972208 26.14886427 26.27444357
#  26.2703697 ]
#
#
# Forecasted values for city C071:
# [23.90285933 23.92858043 23.91964052 24.01438522 24.0587559  23.81173756
#  23.85725431]
#
#
# Forecasted values for city C072:
# [-6.72349845 -7.00980991 -7.22911335 -7.09161568 -7.05687536 -6.81409091
#  -6.59585646]
#
#
# Forecasted values for city C073:
# [-0.5777996  -0.64701    -0.69607314 -0.65759215 -0.56646354 -0.73973683
#  -0.88199394]
#
#
# Forecasted values for city C074:
# [23.45294829 23.40988524 23.27604357 23.22635687 23.2613165  23.24392822
#  23.11701054]
#
#
# Forecasted values for city C076:
# [27.25768025 27.34091366 27.27887451 27.23561139 27.31064416 27.27936476
#  27.17347865]
#
#
# Forecasted values for city C077:
# [1.22949198 1.12405234 0.80994416 0.90495357 0.95153018 0.5481317
#  0.21731171]
#
#
# Forecasted values for city C078:
# [20.08764629 19.90912791 19.8374022  19.72582758 19.78075474 19.80243774
#  19.66666801]
#
#
# Forecasted values for city C079:
# [3.47161396 3.13697947 2.69938004 2.51529011 2.49684788 2.50603288
#  2.40246848]
#
#
# Forecasted values for city C081:
# [20.75980092 20.6636267  20.67697861 20.51817778 20.53749982 20.54777786
#  20.503576  ]
#
#
# Forecasted values for city C082:
# [26.0224727  25.99519417 26.00202421 25.96235311 25.93562272 25.89354283
#  25.84887809]
#
#
# Forecasted values for city C083:
# [27.88669901 27.9171428  27.87965501 27.91210355 27.87598517 27.96154098
#  28.01456137]
#
#
# Forecasted values for city C084:
# [6.54359211 6.55957433 6.41699538 6.14744037 6.1208026  6.27723094
#  6.34587122]
#
#
# Forecasted values for city C085:
# [15.06178517 14.98203352 15.05519171 15.23253135 15.56017693 15.3726941
#  15.1835381 ]
#
#
# Forecasted values for city C086:
# [24.08070626 24.06013159 24.09908067 24.00021477 23.83384917 23.71437149
#  23.48033159]
#
#
# Forecasted values for city C087:
# [5.39170296 4.98702221 4.46177251 4.24260739 4.24188371 4.36287618
#  3.89927487]
#
#
# Forecasted values for city C088:
# [27.44766675 27.39182078 27.43792359 27.34839781 27.45806912 27.41899634
#  27.25690699]
#
#
# Forecasted values for city C089:
# [27.04525337 27.00826444 27.04394705 26.97464768 27.09363987 27.11303134
#  26.95192725]
#
#
# Forecasted values for city C090:
# [3.75523962 3.79978438 3.56430988 3.393953   3.37416516 3.30542567
#  3.09667022]
#
#
# Forecasted values for city C091:
# [27.64042397 27.83233081 27.75181533 27.76817502 27.78692556 27.82199584
#  27.85011532]
#
#
# Forecasted values for city C092:
# [23.52954644 23.51104935 23.41798733 23.60679417 23.71871704 23.78199227
#  23.50898731]
#
#
# Forecasted values for city C093:
# [-2.80272965 -2.96965668 -3.02372766 -2.99771689 -2.99965179 -2.73958416
#  -2.47820347]
#
#
# Forecasted values for city C094:
# [7.58658135 7.30723738 6.9853646  6.99150706 6.95081058 6.71490494
#  6.41049429]
#
#
# Forecasted values for city C095:
# [27.01013789 27.04209237 27.10874998 27.09242692 27.10634123 27.06896794
#  27.01175748]
#
#
# Forecasted values for city C096:
# [23.26360387 23.25843175 23.3737365  23.66496282 23.60343689 23.53367439
#  23.53585683]
#
#
# Forecasted values for city C097:
# [-0.95823633 -0.85365212 -0.79862816 -0.58855681 -0.44385337 -0.52578861
#  -0.40962792]
#
#
# Forecasted values for city C098:
# [7.83341567 7.70469537 7.73135568 7.62381227 7.4334647  7.17598925
#  6.96547552]
#
#
# Forecasted values for city C099:
# [5.49771798 5.55686656 5.51108617 5.38071075 5.68641924 5.90054957
#  5.84219748]
#
#
# Forecasted values for city C100:
# [23.7139458  23.65120624 23.64043209 23.49826789 23.52367383 23.45479342
#  23.41279381]
#
#
# Forecasted values for city C101:
# [27.937357   27.79944284 27.87801279 27.9801096  28.03804488 28.02935368
#  27.98367754]
#
#
# Forecasted values for city C102:
# [3.27906203 3.41062587 3.28402914 2.96223295 2.46473648 2.14661757
#  1.99213853]
#
#
# Forecasted values for city C103:
# [4.57813389 4.48291918 4.63127407 4.77453455 5.01791125 5.29651606
#  4.91983766]
#
#
# Forecasted values for city C104:
# [28.68561701 28.75724679 28.78166791 28.80339781 28.79024726 28.81122079
#  28.76624902]
#
#
# Forecasted values for city C105:
# [ 0.32706976  0.22813222 -0.20230195 -0.2646457  -0.22612973 -0.65098185
#  -0.92239147]
#
#
# Forecasted values for city C106:
# [21.00122288 20.67371605 20.44686744 20.37785383 20.36593167 20.35443784
#  20.4495617 ]
#
#
# Forecasted values for city C107:
# [8.22159898 8.09682041 8.18543168 8.00936387 7.67103498 7.46509149
#  7.40938541]
#
#
# Forecasted values for city C108:
# [22.3289068  22.38757862 22.44817714 22.67528768 22.61740489 22.51804716
#  22.6985318 ]
#
#
# Forecasted values for city C109:
# [3.50460014 3.52484145 3.64332359 3.46365482 3.8715819  4.07935228
#  4.19043504]
#
#
# Forecasted values for city C110:
# [27.95429408 28.07349288 28.06396738 28.04391566 27.98994127 28.09525336
#  28.09174393]
#
#
# Forecasted values for city C111:
# [26.79952259 26.81760802 26.81250573 26.80937428 26.75822345 26.75083495
#  26.69275653]
#
#
# Forecasted values for city C112:
# [21.18101265 21.26222826 21.05043828 21.03257889 21.03142593 21.08293863
#  20.91951827]
#
#
# Forecast data has been saved to 'prophet.csv'

# %%
import pandas as pd
from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics

# Load the updated dataset
data = pd.read_csv('data/part_1/historical_weather_without_outliers.csv')

# Convert the 'date' column to datetime format
data['date'] = pd.to_datetime(data['date'])

# Function to train a Prophet model for a given city
def train_prophet_model(city_data):
    # Prepare the data for Prophet
    prophet_data = city_data.rename(columns={'date': 'ds', 'avg_temp_c': 'y'})

    # Define the Prophet model with tuned hyperparameters
    model = Prophet(changepoint_prior_scale=0.5, seasonality_prior_scale=10.0)

    # Fit the model
    model.fit(prophet_data)

    return model

# Dictionary to store Prophet models for each city
prophet_models = {}

# Train a Prophet model for each city
for city_id, city_data in data.groupby('city_id'):
    prophet_models[city_id] = train_prophet_model(city_data)

# Function to forecast using the trained Prophet model
def forecast_prophet_model(model, steps):
    future = model.make_future_dataframe(periods=steps)
    forecast = model.predict(future)
    return forecast.tail(steps)['yhat']

# Dictionary to store forecasted values for each city
prophet_forecasts = {}

# Forecast the first week of 2019 for each city and print the forecasted values
for city_id, model in prophet_models.items():
    forecast = forecast_prophet_model(model, steps=7)
    prophet_forecasts[city_id] = forecast
    print(f"Forecasted values for city {city_id}:")
    print(forecast.values)
    print("\n")

# Save the forecasted values to a CSV file
forecast_data = []
submission_id = 1
for city_id, forecast in prophet_forecasts.items():
    for temp in forecast:
        forecast_data.append({'submission_ID': submission_id, 'avg_temp_c': round(temp, 2)})
        submission_id += 1

forecast_df = pd.DataFrame(forecast_data)
forecast_df.to_csv('data/part_1/forcasted_data/prophet_optimized.csv', index=False)

print("Forecast data has been saved to 'prophet_optimized.csv'")
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/x_ifg7h9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/bwy5wazh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28341', 'data', 'file=/tmp/tmpea5xgirb/x_ifg7h9.json', 'init=/tmp/tmpea5xgirb/bwy5wazh.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model058co8tw/prophet_model-20240623090328.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:03:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:03:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/jt58siy_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/5pafzcxy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31800', 'data', 'file=/tmp/tmpea5xgirb/jt58siy_.json', 'init=/tmp/tmpea5xgirb/5pafzcxy.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modellh_e0k8b/prophet_model-20240623090329.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:03:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:03:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/eoe77tza.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/38xgnmt7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=17243', 'data', 'file=/tmp/tmpea5xgirb/eoe77tza.json', 'init=/tmp/tmpea5xgirb/38xgnmt7.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model0y9jbli4/prophet_model-20240623090330.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:03:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:03:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/o1x6a_f0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/7ugkrezu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95212', 'data', 'file=/tmp/tmpea5xgirb/o1x6a_f0.json', 'init=/tmp/tmpea5xgirb/7ugkrezu.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelow7c36jb/prophet_model-20240623090331.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:03:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:03:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/4rfiadwa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/8hpb34_r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48259', 'data', 'file=/tmp/tmpea5xgirb/4rfiadwa.json', 'init=/tmp/tmpea5xgirb/8hpb34_r.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model4ybq_sgw/prophet_model-20240623090332.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:03:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:03:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/8xkbd_i9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/n0gkz0ny.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64864', 'data', 'file=/tmp/tmpea5xgirb/8xkbd_i9.json', 'init=/tmp/tmpea5xgirb/n0gkz0ny.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model9kdpmpk1/prophet_model-20240623090333.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:03:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:03:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/e6e8lx8g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/pzvtmk90.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14474', 'data', 'file=/tmp/tmpea5xgirb/e6e8lx8g.json', 'init=/tmp/tmpea5xgirb/pzvtmk90.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model3v2djlye/prophet_model-20240623090334.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:03:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:03:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/a1rg5hna.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/3d1jdayp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/hljx9x4m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57076', 'data', 'file=/tmp/tmpea5xgirb/mdx3frkw.json', 'init=/tmp/tmpea5xgirb/hljx9x4m.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modeltyhckzom/prophet_model-20240623090415.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/02swxays.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/uz7mu2w8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37488', 'data', 'file=/tmp/tmpea5xgirb/02swxays.json', 'init=/tmp/tmpea5xgirb/uz7mu2w8.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modeltvvyprvb/prophet_model-20240623090416.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/1c_lxx27.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/oykhoaqo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58736', 'data', 'file=/tmp/tmpea5xgirb/1c_lxx27.json', 'init=/tmp/tmpea5xgirb/oykhoaqo.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model2tzzfxm6/prophet_model-20240623090418.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/nsm4jd_4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/3y88t7ax.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42721', 'data', 'file=/tmp/tmpea5xgirb/nsm4jd_4.json', 'init=/tmp/tmpea5xgirb/3y88t7ax.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelxctjep9z/prophet_model-20240623090419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/9o3nnrgx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/9u90xnts.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98957', 'data', 'file=/tmp/tmpea5xgirb/9o3nnrgx.json', 'init=/tmp/tmpea5xgirb/9u90xnts.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelwzvue6es/prophet_model-20240623090419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# ...
# 09:04:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/ao3i5q4a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/b1op33rs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25766', 'data', 'file=/tmp/tmpea5xgirb/ao3i5q4a.json', 'init=/tmp/tmpea5xgirb/b1op33rs.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelj_m015pz/prophet_model-20240623090457.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/21jl4ryj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/kzksziev.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60202', 'data', 'file=/tmp/tmpea5xgirb/21jl4ryj.json', 'init=/tmp/tmpea5xgirb/kzksziev.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelygb6zqng/prophet_model-20240623090458.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/crhue6qc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/s80b01qn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83355', 'data', 'file=/tmp/tmpea5xgirb/crhue6qc.json', 'init=/tmp/tmpea5xgirb/s80b01qn.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_model8_32q_s5/prophet_model-20240623090458.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:04:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/1bgsnb2u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpea5xgirb/yukcew8_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80449', 'data', 'file=/tmp/tmpea5xgirb/1bgsnb2u.json', 'init=/tmp/tmpea5xgirb/yukcew8_.json', 'output', 'file=/tmp/tmpea5xgirb/prophet_modelwl0ih5go/prophet_model-20240623090459.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:04:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:05:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Forecasted values for city C001:
# [8.57760713 8.24284428 7.89149926 7.54925324 7.35625224 7.47378643
#  7.54394369]
#
#
# Forecasted values for city C002:
# [14.53801678 14.4228933  14.23880501 14.05708172 13.95859943 13.81236961
#  13.71042404]
#
#
# Forecasted values for city C003:
# [26.90117439 26.95675329 26.91107869 26.89927327 26.96599461 26.95354708
#  26.9068445 ]
#
#
# Forecasted values for city C004:
# [-1.2470981  -1.33920717 -1.2436918  -1.11571077 -1.23670941 -1.36084268
#  -1.17286043]
#
#
# Forecasted values for city C005:
# [25.14812946 25.18266463 25.07501371 25.36153239 25.23794829 25.14359637
#  25.31592499]
#
#
# Forecasted values for city C007:
# [19.24912523 19.44888758 19.79761304 19.98780441 20.26778825 20.27539122
#  19.86458333]
#
#
# Forecasted values for city C008:
# [3.17488325 3.25662244 3.086278   3.01846065 3.16674108 2.92034917
#  2.56244616]
#
#
# Forecasted values for city C009:
# [20.55162413 20.49503358 20.43217579 20.38076624 20.57830221 20.53705201
#  20.32763431]
#
#
# Forecasted values for city C010:
# [19.54774751 19.64957342 19.65526112 19.60847042 19.70576892 19.77335878
#  19.76714171]
#
#
# Forecasted values for city C011:
# [-2.15618653 -2.35096873 -2.67560829 -2.76104372 -2.83585518 -2.99269213
#  -3.31823731]
#
#
# Forecasted values for city C012:
# [6.97514506 6.86336055 6.96228234 6.89226852 6.62794    6.29874847
#  6.11992084]
#
#
# Forecasted values for city C013:
# [3.07759234 2.63024549 1.93934159 1.7853564  1.80034637 1.90978986
#  1.45388349]
#
#
# Forecasted values for city C014:
# [3.10084892 2.78950164 2.34897194 1.98377647 1.71789793 1.79078474
#  1.71713505]
#
#
# Forecasted values for city C015:
# [24.16810763 24.11772739 24.09877868 24.12162389 24.16635996 24.04017723
#  24.00777282]
#
#
# Forecasted values for city C016:
# [20.57993538 20.47657205 20.48302966 20.31751954 20.33033412 20.33439593
#  20.28321842]
#
#
# Forecasted values for city C017:
# [27.58017774 27.58693949 27.59082296 27.59242922 27.63876659 27.63927438
#  27.58575217]
#
#
# Forecasted values for city C018:
# [-4.70653036 -4.81134002 -5.00117285 -4.93449142 -5.25628079 -5.71076262
#  -6.28437428]
#
#
# Forecasted values for city C020:
# [25.9732958  25.96882996 26.0916651  26.13048381 25.90607102 25.89830352
#  25.99287288]
#
#
# Forecasted values for city C022:
# [-4.76356375 -4.72671774 -4.79362996 -4.61042756 -4.75574885 -4.37711042
#  -4.22802936]
#
#
# Forecasted values for city C023:
# [27.07216131 27.03050939 27.01522064 26.83079004 26.74936623 26.63991172
#  26.57463074]
#
#
# Forecasted values for city C024:
# [5.47507753 5.33149338 5.0553282  4.93793571 4.96555467 4.75545641
#  4.50131959]
#
#
# Forecasted values for city C025:
# [2.67984993 2.70546327 2.54556488 2.55161711 2.66109279 2.45730567
#  2.05776808]
#
#
# Forecasted values for city C027:
# [-13.76920267 -14.3033488  -14.01295887 -14.01929071 -14.33854134
#  -14.3375556  -13.88496491]
#
#
# Forecasted values for city C028:
# [25.23254956 25.27378468 25.2263264  25.25955965 25.09267826 25.1128407
#  25.10697263]
#
#
# Forecasted values for city C029:
# [24.95493236 24.99177277 24.86182078 24.92137359 24.88770294 24.84663964
#  24.99080756]
#
#
# Forecasted values for city C030:
# [27.57730558 27.58276164 27.63223297 27.63561985 27.59128747 27.56208753
#  27.56873281]
#
#
# Forecasted values for city C031:
# [-1.65894354 -1.79805927 -2.05141677 -2.0499401  -2.00022259 -2.27003395
#  -2.39838854]
#
#
# Forecasted values for city C033:
# [-1.12507726 -1.38119781 -1.51864586 -1.57316817 -1.60948882 -1.85405931
#  -1.94287756]
#
#
# Forecasted values for city C034:
# [7.56206588 7.33979161 7.26616727 7.24837489 7.17370012 6.85630633
#  6.64110936]
#
#
# Forecasted values for city C035:
# [27.59134692 27.5987049  27.66340466 27.61670446 27.6619559  27.55890382
#  27.53499839]
#
#
# Forecasted values for city C036:
# [0.65581739 0.60171699 0.47346822 0.64554792 0.63717112 0.38201558
#  0.17505788]
#
#
# Forecasted values for city C037:
# [3.85472232 3.88608828 3.88593596 4.03521652 3.92832917 3.60665843
#  3.40025973]
#
#
# Forecasted values for city C038:
# [28.38361262 28.34161533 28.35389808 28.36706379 28.30939465 28.24863675
#  28.20844797]
#
#
# Forecasted values for city C039:
# [12.31928494 12.06845001 11.84435175 11.49645526 11.36857053 11.41759265
#  11.45419957]
#
#
# Forecasted values for city C040:
# [27.30988628 27.24818814 27.28874335 27.19378255 27.29778499 27.25283512
#  27.08486987]
#
#
# Forecasted values for city C042:
# [20.60262674 20.58074948 20.65224937 20.79426472 20.90361524 20.84880114
#  20.93741772]
#
#
# Forecasted values for city C043:
# [2.94578082 2.82436348 2.49163482 2.44594651 2.48005829 2.39641239
#  2.00650626]
#
#
# Forecasted values for city C044:
# [12.31534781 12.54600373 12.81341956 13.00148974 12.96934009 12.93754751
#  12.98930685]
#
#
# Forecasted values for city C045:
# [27.66071249 27.64703484 27.59465977 27.63235586 27.52400702 27.55349153
#  27.54889313]
#
#
# Forecasted values for city C046:
# [6.45544731 6.49702339 6.57323794 6.78856804 6.84830984 6.7731498
#  6.57455537]
#
#
# Forecasted values for city C047:
# [6.99788922 6.99986467 7.14697666 6.93925181 6.74795276 6.57380226
#  6.57751885]
#
#
# Forecasted values for city C048:
# [9.83753986 9.4960989  9.15202997 9.0106297  9.11815566 9.31931191
#  9.14767338]
#
#
# Forecasted values for city C049:
# [6.16337004 6.0962845  5.99210772 5.96846403 5.7503173  5.64728427
#  5.68262194]
#
#
# Forecasted values for city C051:
# [28.06868315 28.08001409 27.97020289 28.09509028 28.16296239 28.14658255
#  28.1838842 ]
#
#
# Forecasted values for city C053:
# [-3.88428033 -4.52754067 -4.67034711 -4.55253847 -4.68656396 -5.02111701
#  -5.2887971 ]
#
#
# Forecasted values for city C054:
# [-1.80724841 -2.03842373 -2.35570154 -2.36334429 -2.40606902 -2.51489626
#  -2.7841546 ]
#
#
# Forecasted values for city C055:
# [5.09115612 4.9516075  4.81622462 4.90139784 4.60774284 4.37997612
#  4.08202222]
#
#
# Forecasted values for city C056:
# [3.74792789 3.37058059 3.04364166 2.91085393 2.5916074  2.49383178
#  2.38448542]
#
#
# Forecasted values for city C057:
# [20.73799029 20.72391511 20.71789156 20.75794252 20.69239839 20.61943087
#  20.61382608]
#
#
# Forecasted values for city C058:
# [24.41947154 24.53120251 24.48310701 24.40921341 24.52910511 24.42887029
#  24.1686403 ]
#
#
# Forecasted values for city C059:
# [13.97596314 13.7320507  13.5362042  13.44742949 13.32440236 13.3686202
#  13.45292318]
#
#
# Forecasted values for city C061:
# [22.70664361 22.68030437 22.75108955 22.77790886 22.79684154 22.77895693
#  22.87120439]
#
#
# Forecasted values for city C062:
# [10.31890658 10.1253738   9.96016371  9.81314125  9.65006459  9.75313961
#   9.64709547]
#
#
# Forecasted values for city C064:
# [8.09993306 7.74150464 7.51789909 7.22745452 7.05820089 6.93649181
#  7.03678581]
#
#
# Forecasted values for city C065:
# [13.27224983 13.081444   12.84649866 12.7302106  12.85990905 12.67887795
#  12.63884695]
#
#
# Forecasted values for city C066:
# [27.17678718 27.19179822 27.09765121 27.20526158 27.23860116 27.20552538
#  27.18407837]
#
#
# Forecasted values for city C067:
# [23.91294731 23.84374788 23.77978121 23.81005874 23.8519392  23.79538704
#  23.74340932]
#
#
# Forecasted values for city C068:
# [10.31596317 10.37237916 10.45558498 10.40056912 10.48125106 10.45985389
#  10.52793312]
#
#
# Forecasted values for city C069:
# [17.63533024 17.60958311 17.46261781 17.36066182 17.47481352 17.56445677
#  17.84768151]
#
#
# Forecasted values for city C070:
# [26.35245321 26.31194447 26.36095899 26.2483471  26.27893966 26.40618486
#  26.40381208]
#
#
# Forecasted values for city C071:
# [23.75777928 23.7851738  23.77394663 23.86610459 23.90769977 23.65775674
#  23.70005267]
#
#
# Forecasted values for city C072:
# [-7.02456525 -7.2993162  -7.51253358 -7.36944816 -7.32975654 -7.08271111
#  -6.86104798]
#
#
# Forecasted values for city C073:
# [-0.94447049 -0.99718801 -1.03647617 -0.98874786 -0.88921535 -1.05486487
#  -1.19055202]
#
#
# Forecasted values for city C074:
# [24.20904526 24.20222611 24.09915315 24.07947563 24.14396212 24.15559555
#  24.05550507]
#
#
# Forecasted values for city C076:
# [27.20569752 27.28497728 27.21964279 27.17314848 27.24504785 27.21071783
#  27.10193339]
#
#
# Forecasted values for city C077:
# [1.6493262  1.58026786 1.29135783 1.41095741 1.48100664 1.10006397
#  0.7904181 ]
#
#
# Forecasted values for city C078:
# [20.99300807 20.84756792 20.80284133 20.71718939 20.79685248 20.841686
#  20.72731351]
#
#
# Forecasted values for city C079:
# [3.95939891 3.63388149 3.20378124 3.02703903 3.01554779 3.03150336
#  2.93433874]
#
#
# Forecasted values for city C081:
# [20.57993538 20.47657205 20.48302966 20.31751954 20.33033412 20.33439593
#  20.28321842]
#
#
# Forecasted values for city C082:
# [25.80459966 25.76212698 25.75714291 25.70626354 25.66887382 25.6169272
#  25.56327238]
#
#
# Forecasted values for city C083:
# [27.9858909  28.01832651 27.98318333 28.01798533 27.98422236 28.07212832
#  28.12750556]
#
#
# Forecasted values for city C084:
# [6.39732462 6.38921434 6.23071596 5.94654194 5.90642932 6.05125974
#  6.11015823]
#
#
# Forecasted values for city C085:
# [15.5259283  15.46212262 15.54874847 15.73908126 16.07916378 15.90334335
#  15.72503366]
#
#
# Forecasted values for city C086:
# [24.70955627 24.7024046  24.75114589 24.66110656 24.50244914 24.38910895
#  24.15951552]
#
#
# Forecasted values for city C087:
# [5.96278373 5.57076902 5.05704182 4.84916676 4.85939494 4.99101794
#  4.53763702]
#
#
# Forecasted values for city C088:
# [27.30988628 27.24818814 27.28874335 27.19378255 27.29778499 27.25283512
#  27.08486987]
#
#
# Forecasted values for city C089:
# [27.07825674 27.04364583 27.08069714 27.01262049 27.13262475 27.15278633
#  26.99216998]
#
#
# Forecasted values for city C090:
# [3.8854713  3.91331725 3.67056207 3.49460764 3.4705425  3.39973939
#  3.19109737]
#
#
# Forecasted values for city C091:
# [27.48388282 27.67025684 27.58503211 27.59679708 27.61075457 27.64197827
#  27.6661241 ]
#
#
# Forecasted values for city C092:
# [22.89268584 22.86337782 22.75874221 22.93813053 23.04384881 23.09841161
#  22.8201243 ]
#
#
# Forecasted values for city C093:
# [-2.97088195 -3.11861917 -3.1606476  -3.1232919  -3.11473907 -2.84519525
#  -2.57553018]
#
#
# Forecasted values for city C094:
# [7.28761164 6.99896472 6.66954812 6.66856649 6.62118787 6.3790947
#  6.06906842]
#
#
# Forecasted values for city C095:
# [26.92702967 26.95651578 27.0211073  27.00272928 27.0166666  26.97629494
#  26.91710887]
#
#
# Forecasted values for city C096:
# [23.20674875 23.20784713 23.32536096 23.61805984 23.55756441 23.48809459
#  23.48974512]
#
#
# Forecasted values for city C097:
# [-0.77822492 -0.67068257 -0.61277525 -0.39989479 -0.25247966 -0.33182769
#  -0.21322517]
#
#
# Forecasted values for city C098:
# [8.08001877 7.95520087 7.98508344 7.87958033 7.69184922 7.43826795
#  7.2283069 ]
#
#
# Forecasted values for city C099:
# [5.22717273 5.27520729 5.22045581 5.08138239 5.37873513 5.58495016
#  5.51917139]
#
#
# Forecasted values for city C100:
# [23.88990302 23.82740781 23.81690813 23.67372061 23.6981791  23.62885894
#  23.58519914]
#
#
# Forecasted values for city C101:
# [27.79470488 27.64706392 27.71816209 27.8130533  27.8641435  27.84904191
#  27.79745301]
#
#
# Forecasted values for city C102:
# [3.74538387 3.86890399 3.74628888 3.42478523 2.92758935 2.60982095
#  2.45575442]
#
#
# Forecasted values for city C103:
# [4.96774351 4.8833645  5.04069762 5.19255969 5.44389545 5.72957938
#  5.35914059]
#
#
# Forecasted values for city C104:
# [28.80281788 28.87696696 28.90414518 28.92898407 28.9186508  28.9422541
#  28.90029366]
#
#
# Forecasted values for city C105:
# [ 0.74567701  0.66872033  0.25454245  0.2084088   0.26263512 -0.14669741
#  -0.40298351]
#
#
# Forecasted values for city C106:
# [21.87786992 21.58152142 21.38052483 21.33634557 21.34800884 21.35842037
#  21.47372874]
#
#
# Forecasted values for city C107:
# [7.76333907 7.64060671 7.72915579 7.55307137 7.21470282 7.0088189
#  6.95317368]
#
#
# Forecasted values for city C108:
# [22.65521781 22.71208215 22.77023663 22.99461347 22.93366725 22.83088558
#  23.0075901 ]
#
#
# Forecasted values for city C109:
# [2.97052774 2.98893144 3.10319589 2.91928222 3.3229374  3.52640487
#  3.63314258]
#
#
# Forecasted values for city C110:
# [27.15718425 27.25119225 27.22055233 27.17955364 27.10547553 27.1916607
#  27.1703294 ]
#
#
# Forecasted values for city C111:
# [26.97115709 26.99746404 26.99989268 27.00419616 26.96000363 26.95897094
#  26.90728354]
#
#
# Forecasted values for city C112:
# [20.94994742 21.02657216 20.80926107 20.78656737 20.7808344  20.82739777
#  20.65916828]
#
#
# Forecast data has been saved to 'prophet_optimized.csv'
